# %% [markdown]
# # Task 3
#
# Surya Dutt Sharma
#
# Exloratory Data Analysis on Dataset - Terrorism
#
# 1st we are going to import all the import libraries which we are going to use.
#
# 2nd we will import the dataset on which we are going to perform the Exploratory Data Analysis

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly as py
# %matplotlib inline

# %%
df = pd.read_csv("globalterrorismdb_dist.csv",encoding='latin1')
# Out:
# C:\Users\surya\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
df.shape
# Out:
# (181691, 135)

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
df.columns.tolist()
# Out:
# ['eventid',
#  'iyear',
#  'imonth',
#  'iday',
#  'approxdate',
#  'extended',
#  'resolution',
#  'country',
#  'country_txt',
#  'region',
#  'region_txt',
#  'provstate',
#  'city',
#  'latitude',
#  'longitude',
#  'specificity',
#  'vicinity',
#  'location',
#  'summary',
#  'crit1',
#  'crit2',
#  'crit3',
#  'doubtterr',
#  'alternative',
#  'alternative_txt',
#  'multiple',
#  'success',
#  'suicide',
#  'attacktype1',
#  'attacktype1_txt',
#  'attacktype2',
#  'attacktype2_txt',
#  'attacktype3',
#  'attacktype3_txt',
#  'targtype1',
#  'targtype1_txt',
#  'targsubtype1',
#  'targsubtype1_txt',
#  'corp1',
#  'target1',
#  'natlty1',
#  'natlty1_txt',
#  'targtype2',
#  'targtype2_txt',
#  'targsubtype2',
#  'targsubtype2_txt',
#  'corp2',
#  'target2',
#  'natlty2',
#  'natlty2_txt',
#  'targtype3',
#  'targtype3_txt',
#  'targsubtype3',
#  'targsubtype3_txt',
#  'corp3',
#  'target3',
#  'natlty3',
#  'natlty3_txt',
#  'gname',
#  'gsubname',
#  'gname2',
#  'gsubname2',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
df.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
corelation = df.corr()
corelation
# Out:
#             eventid     iyear    imonth      iday  extended   country  \
# eventid    1.000000  0.999996  0.002706  0.018336  0.091761 -0.135039
# iyear      0.999996  1.000000  0.000139  0.018254  0.091754 -0.135023
# imonth     0.002706  0.000139  1.000000  0.005497 -0.000468 -0.006305
# iday       0.018336  0.018254  0.005497  1.000000 -0.004700  0.003468
# extended   0.091761  0.091754 -0.000468 -0.004700  1.000000 -0.020466
# ...             ...       ...       ...       ...       ...       ...
# nreleased -0.181612 -0.181556 -0.011535  0.001765 -0.192155 -0.044331
# INT_LOG   -0.143600 -0.143601 -0.002302 -0.001540  0.071768  0.069904
# INT_IDEO  -0.133252 -0.133253 -0.002034 -0.001621  0.075147  0.067564
# INT_MISC  -0.077852 -0.077847 -0.002554 -0.002027  0.027335  0.207281
# INT_ANY   -0.175605 -0.175596 -0.006336 -0.001199  0.080767  0.153118
#
#              region  latitude  longitude  specificity  ...  ransomamt  \
# ...

# %%
df = df[['iyear','imonth','iday','country_txt','provstate','region_txt','city','natlty1_txt','latitude','longitude','nkill','nwound','suicide',
 'attacktype1_txt','gname','targtype1_txt','weaptype1_txt','weaptype1','motive']]

# %%
df.rename(columns={'iyear':'Year','imonth':'Month',
 'iday':'Day',
 'country_txt':'Country','provstate':'State',
 'region_txt':'Region','city':'City',
 'latitude':'Latitude',
 'longitude':'Longitude','natlty1_txt':'Nationality','nkill':'Killed','nwound':'Wounded','suicide':'Sucide',
 'attacktype1_txt':'Attack Type','gname':'Group_Name','targtype1_txt':'Target_Type','weaptype1_txt':'Weapon_Type','weaptype1':'Weapon','motive':'Motive'},inplace = True)

# %%
df
# Out:
#         Year  Month  Day             Country            State  \
# 0       1970      7    2  Dominican Republic              NaN
# 1       1970      0    0              Mexico          Federal
# 2       1970      1    0         Philippines           Tarlac
# 3       1970      1    0              Greece           Attica
# 4       1970      1    0               Japan          Fukouka
# ...      ...    ...  ...                 ...              ...
# 181686  2017     12   31             Somalia  Middle Shebelle
# 181687  2017     12   31               Syria         Lattakia
# 181688  2017     12   31         Philippines      Maguindanao
# 181689  2017     12   31               India          Manipur
# 181690  2017     12   31         Philippines      Maguindanao
#
#                              Region           City         Nationality  \
# 0       Central America & Caribbean  Santo Domingo  Dominican Republic
# 1                     North America    Mexico city             Belgium
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 19 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Year         181691 non-null  int64
#  1   Month        181691 non-null  int64
#  2   Day          181691 non-null  int64
#  3   Country      181691 non-null  object
#  4   State        181270 non-null  object
#  5   Region       181691 non-null  object
#  6   City         181257 non-null  object
#  7   Nationality  180132 non-null  object
#  8   Latitude     177135 non-null  float64
#  9   Longitude    177134 non-null  float64
#  10  Killed       171378 non-null  float64
#  11  Wounded      165380 non-null  float64
#  12  Sucide       181691 non-null  int64
#  13  Attack Type  181691 non-null  object
#  14  Group_Name   181691 non-null  object
#  15  Target_Type  181691 non-null  object
#  16  Weapon_Type  181691 non-null  object
#  17  Weapon       181691 non-null  int64
# ...

# %%
df.isnull()
# Out:
#          Year  Month    Day  Country  State  Region   City  Nationality  \
# 0       False  False  False    False   True   False  False        False
# 1       False  False  False    False  False   False  False        False
# 2       False  False  False    False  False   False  False        False
# 3       False  False  False    False  False   False  False        False
# 4       False  False  False    False  False   False  False        False
# ...       ...    ...    ...      ...    ...     ...    ...          ...
# 181686  False  False  False    False  False   False  False        False
# 181687  False  False  False    False  False   False  False        False
# 181688  False  False  False    False  False   False  False        False
# 181689  False  False  False    False  False   False  False        False
# 181690  False  False  False    False  False   False  False        False
#
#         Latitude  Longitude  Killed  Wounded  Sucide  Attack Type  Group_Name  \
# ...

# %%
df.isnull().sum()
# Out:
# Year                0
# Month               0
# Day                 0
# Country             0
# State             421
# Region              0
# City              434
# Nationality      1559
# Latitude         4556
# Longitude        4557
# Killed          10313
# Wounded         16311
# Sucide              0
# Attack Type         0
# Group_Name          0
# Target_Type         0
# Weapon_Type         0
# Weapon              0
# Motive         131130
# dtype: int64

# %%
corelation = df.corr()
corelation
# Out:
#                Year     Month       Day  Latitude  Longitude    Killed  \
# Year       1.000000  0.000139  0.018254  0.166933   0.003917  0.015341
# Month      0.000139  1.000000  0.005497 -0.015978  -0.003880  0.003463
# Day        0.018254  0.005497  1.000000  0.003423  -0.002285 -0.003693
# Latitude   0.166933 -0.015978  0.003423  1.000000   0.001463 -0.018124
# Longitude  0.003917 -0.003880 -0.002285  0.001463   1.000000 -0.000562
# Killed     0.015341  0.003463 -0.003693 -0.018124  -0.000562  1.000000
# Wounded    0.015273  0.002938 -0.001268  0.015988   0.000223  0.534375
# Sucide     0.137736  0.003071  0.003593  0.068682   0.000486  0.136086
# Weapon    -0.011737  0.007863 -0.003019 -0.011710   0.001582  0.004038
#
#             Wounded    Sucide    Weapon
# Year       0.015273  0.137736 -0.011737
# Month      0.002938  0.003071  0.007863
# Day       -0.001268  0.003593 -0.003019
# Latitude   0.015988  0.068682 -0.011710
# Longitude  0.000223  0.000486  0.001582
# ...

# %%
df['Wounded'] = df['Wounded'].fillna(0).astype(int)
df['Killed'] = df['Killed'].fillna(0).astype(int)

# %%
df['Casualities'] = df['Wounded'] + df['Killed']

# %%
df
# Out:
#         Year  Month  Day             Country            State  \
# 0       1970      7    2  Dominican Republic              NaN
# 1       1970      0    0              Mexico          Federal
# 2       1970      1    0         Philippines           Tarlac
# 3       1970      1    0              Greece           Attica
# 4       1970      1    0               Japan          Fukouka
# ...      ...    ...  ...                 ...              ...
# 181686  2017     12   31             Somalia  Middle Shebelle
# 181687  2017     12   31               Syria         Lattakia
# 181688  2017     12   31         Philippines      Maguindanao
# 181689  2017     12   31               India          Manipur
# 181690  2017     12   31         Philippines      Maguindanao
#
#                              Region           City         Nationality  \
# 0       Central America & Caribbean  Santo Domingo  Dominican Republic
# 1                     North America    Mexico city             Belgium
# ...

# %%
df.describe()
# Out:
#                 Year          Month            Day       Latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean     2002.638997       6.467277      15.505644      23.498343
# std        13.259430       3.388303       8.814045      18.569242
# min      1970.000000       0.000000       0.000000     -53.154613
# 25%      1991.000000       4.000000       8.000000      11.510046
# 50%      2009.000000       6.000000      15.000000      31.467463
# 75%      2014.000000       9.000000      23.000000      34.685087
# max      2017.000000      12.000000      31.000000      74.633553
#
#           Longitude         Killed        Wounded         Sucide  \
# count  1.771340e+05  181691.000000  181691.000000  181691.000000
# mean  -4.586957e+02       2.266860       2.883291       0.036507
# std    2.047790e+05      11.227057      34.309746       0.187549
# min   -8.618590e+07       0.000000       0.000000       0.000000
# ...

# %% [markdown]
# # Data Visualition

# %%
df.hist(figsize = (30,30))
plt.show()

# %%
print("Highest Number of Attack:", df['Country'].value_counts().idxmax())
# Out:
# Highest Number of Attack: Iraq

# %%
print("Dangerous Country as Per the Highest Number of Attacks:", df['Country'].value_counts().idxmax())
print("Safest Country as Per the Lowest Number of Attacks:", df['Country'].value_counts().idxmin())

print("Groups with Most Number of Attacks:", df['Group_Name'].value_counts().idxmax())
print("Groups with Least Number of Attacks:", df['Group_Name'].value_counts().idxmin())

print("City with Most Number of Attacks:", df['City'].value_counts().idxmax())
print("City with Least Number of Attacks:", df['City'].value_counts().idxmin())

print("Year with Most Number of Attacks:", df['Year'].value_counts().idxmax())
print("Year with Least Number of Attacks:", df['Year'].value_counts().idxmin())

print("Month with Most Number of Attacks:", df['Month'].value_counts().idxmax())
print("Month with Least Number of Attacks:", df['Month'].value_counts().idxmin())

print("Region with Most Number of Attacks:", df['Region'].value_counts().idxmax())
print("Region with Least Number of Attacks:", df['Region'].value_counts().idxmin())

print("Max affected Nationality:", df['Nationality'].value_counts().idxmax())
print("Min affected Nationality:", df['Nationality'].value_counts().idxmin())

print("Max No. of Attack Type:", df['Attack Type'].value_counts().idxmax())
print("Min No. of Attack Type:", df['Attack Type'].value_counts().idxmin())

print("Max No. of Weapon_Type Used:", df['Weapon_Type'].value_counts().idxmax())
print("Min No. of Weapon_Type Used:", df['Weapon_Type'].value_counts().idxmin())
# Out:
# Dangerous Country as Per the Highest Number of Attacks: Iraq
# Safest Country as Per the Lowest Number of Attacks: Vatican City
# Groups with Most Number of Attacks: Unknown
# Groups with Least Number of Attacks: Student Revolutionary Front (FER)
# City with Most Number of Attacks: Unknown
# City with Least Number of Attacks: Dhaperhat
# Year with Most Number of Attacks: 2014
# Year with Least Number of Attacks: 1971
# Month with Most Number of Attacks: 5
# Month with Least Number of Attacks: 0
# Region with Most Number of Attacks: Middle East & North Africa
# Region with Least Number of Attacks: Australasia & Oceania
# Max affected Nationality: Iraq
# Min affected Nationality: St. Lucia
# Max No. of Attack Type: Bombing/Explosion
# Min No. of Attack Type: Hijacking
# Max No. of Weapon_Type Used: Explosives
# Min No. of Weapon_Type Used: Radiological

# %%
sns.countplot(x = 'Year',data =df)
sns.set(rc= {"figure.figsize": (20, 15)})
plt.title(' Highest No. of Attacks per year')
plt.show()

# %%
sns.lineplot(data = df,y = "Killed", x = "Region")
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Killed'>

# %%
sns.lineplot(data = df, x = 'Year', y = 'Region')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Region'>

# %%
df['Wounded'] = df['Wounded'].fillna(0).astype(int)
df['Casualities'] = df['Casualities'].fillna(0).astype(int)

# %%
df.head()
# Out:
#    Year  Month  Day             Country    State                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#             City         Nationality   Latitude   Longitude  Killed  Wounded  \
# 0  Santo Domingo  Dominican Republic  18.456792  -69.951164       1        0
# 1    Mexico city             Belgium  19.371887  -99.086624       0        0
# 2        Unknown       United States  15.478598  120.599741       1        0
# 3         Athens       United States  37.997490   23.762728       0        0
# 4        Fukouka       United States  33.580412  130.396361       0        0
#
# ...

# %%
sns.displot(df,x='Year',kind='kde', fill = 'tree' ,palette = 'colorblind', color = 'r')

# %%
sns.jointplot(x = df['Year'], y = df['Region'])
plt.figure(figsize = (5,5))

# %%
palette = sns.color_palette("mako_r", 8)
sns.lineplot(data = df, x = 'Weapon', y = 'Weapon_Type',size = 'Year', hue = 'Region', sizes = (10,15), markers = True, dashes= True)
# Out:
# <AxesSubplot:xlabel='Weapon', ylabel='Weapon_Type'>

# %%
df.Country.value_counts()[:10]
# Out:
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Name: Country, dtype: int64

# %%
plt.figure(figsize = (15,10))
sns.heatmap(df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
sns.catplot(x = 'Region', y = 'Year', data = df.sort_values("Killed"), kind  = 'boxen', aspect =4, height = 6)
plt.show()

# %%
sns.displot(df,x='Killed',kind='kde', fill = 'tree' ,palette = 'colorblind', color = 'r')

# %%
sns.catplot(x = 'Region', y = 'Year', data = df.sort_values("Sucide"), kind  = 'boxen', aspect =4, height = 6)
plt.show()

# %%
sns.displot(df,x='Sucide',kind='kde', fill = 'tree' ,palette = 'colorblind', color = 'y')

# %%
Casualities_Data=df.loc[:,'Casualities']
print('Total Casualities in Terror Attack:', int(sum(Casualities_Data.dropna())))
# Out:
# Total Casualities in Terror Attack: 935736

# %%
Attack_Data=df.loc[:,'Attack Type']
Attack_year=df.loc[:,'Year']
Kill_Data_New = pd.concat([Casualities_Data,Attack_Data, Attack_year],axis = 1)

# %%
Kill_Data_New.head()
# Out:
#    Casualities                     Attack Type  Year
# 0            1                   Assassination  1970
# 1            0     Hostage Taking (Kidnapping)  1970
# 2            1                   Assassination  1970
# 3            0               Bombing/Explosion  1970
# 4            0  Facility/Infrastructure Attack  1970

# %%
Kill_Data_New.tail()
# Out:
#         Casualities                     Attack Type  Year
# 181686            3                   Armed Assault  2017
# 181687            9               Bombing/Explosion  2017
# 181688            0  Facility/Infrastructure Attack  2017
# 181689            0               Bombing/Explosion  2017
# 181690            0               Bombing/Explosion  2017

# %%
sns.lineplot(data = df, x = 'Year', y = 'Casualities')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Casualities'>

# %% [markdown]
# # What we have Anaysed:-
# Highest number of attackes were helled in Iraq from 1970 to 2010.
#
# Dangerous Country as Per the Highest Number of Attacks: Iraq
#
# Safest Country as Per the Lowest Number of Attacks: Wallis and Futuna.
#
# Groups with Least Number of Attacks: Thanthai Periyar Dravidar Kazhagam (TPDK)
#
# Highest casualities were around year 2000.
#
# City with Least Number of Attacks: Tubingen.
#
# Year with Most Number of Attacks: 2014
#
# Year with Least Number of Attacks: 1971
#
# Month with Most Number of Attacks: 5
#
# Total casualities which occured between the year 1970 to 2000 were 935736.
#
# Region with Most Number of Attacks: Middle East & North Africa.
#
# Region with Least Number of Attacks: Australasia & Oceania.
#
# Max affected Nationality: Iraq
#
# Min affected Nationality: Man, Isle of.
#
# Max No. of Attack Type: Bombing/Explosion
#
# Min No. of Attack Type: Hijacking
#
# Max No. of Weapon_Type Used: Explosives
#
# Min No. of Weapon_Type Used: Radiological
#
# Density of people is more who were died from sucide than terrorist attack.
#
# Highest attacks were done after 2010 to 2020.
